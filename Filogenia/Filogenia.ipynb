#     [Phacochoerus_africanus]    [Lagothrix_lagotricha]  [Pithecia_pithecia] [Aotus_nancymaae]   [Callithrix_jacchus]    [Macaca_mulatta]    [Theropithecus_gelada]  [Macaca_fascicularis]   [Gorilla_gorilla_gorilla]   [Nomascus_leucogenys]   IL13_HUMAN  [Hylobates_lar] [Pan_paniscus]  [Pan_troglodytes]   [Pongo_abelii]  [Pongo_pygmaeus]    [Hylobates_moloch]  [Symphalangus_syndactylus]

# %%
# utilizando o calculator criado anteriormente para o constructor da árvore:
constructor = DistanceTreeConstructor(calculator)

# constrói-se a árvore filogenética resultante do alinhamento múltiplo:
tree = constructor.build_tree(alignment)
tree.rooted = True

print(tree)
# Out:
# Tree(rooted=True)
#     Clade(branch_length=0, name='Inner18')
#         Clade(branch_length=0.0004112830528846152, name='Inner17')
#             Clade(branch_length=0.0010310246394230715, name='Inner15')
#                 Clade(branch_length=0.0009230393629807657, name='[Macaca_mulatta]')
#                 Clade(branch_length=3.849909855769239e-05, name='[Macaca_fascicularis]')
#             Clade(branch_length=0.0007286658653846054, name='Inner16')
#                 Clade(branch_length=0.009871419270833307, name='[Chlorocebus_sabaeus]')
#                 Clade(branch_length=0.0035591321113782447, name='Inner14')
#                     Clade(branch_length=0.004495004507211532, name='Inner11')
#                         Clade(branch_length=0.005514761117788456, name='Inner9')
#                             Clade(branch_length=0.0008289513221154225, name='Inner8')
#                                 Clade(branch_length=0.001449819711538453, name='Inner7')
#                                     Clade(branch_length=0.003952574118589734, name='[Homo_sapiens]')
#                                     Clade(branch_length=0.003739733573717931, name='[Pan_paniscus]')
#                                 Clade(branch_length=0.007684795673076899, name='[Pongo_abelii]')
#                             Clade(branch_length=0.0097479717548077, name='[Hylobates_moloch]')
#                         Clade(branch_length=0.01544001652644229, name='Inner6')
#                             Clade(branch_length=0.02114575628698226, name='Inner5')
#                                 Clade(branch_length=0.025422819368131844, name='[Saimiri_boliviensis_boliviensis]')
#                                 Clade(branch_length=0.010154103708791218, name='[Sapajus_apella]')
#                             Clade(branch_length=0.03459342640532545, name='Inner4')
#                                 Clade(branch_length=0.09280448717948718, name='[Orycteropus_afer_afer]')
#                                 Clade(branch_length=0.016089743589743605, name='Inner3')
#                                     Clade(branch_length=0.0066406249999999695, name='Inner2')
#                                         Clade(branch_length=0.029001696832579207, name='Inner1')
#                                             Clade(branch_length=0.04201388888888889, name='[Dipodomys_spectabilis]')
#                                             Clade(branch_length=0.03875534188034192, name='[Perognathus_longimembris_pacificus]')
#                                         Clade(branch_length=0.045998303167420804, name='[Castor_canadensis]')
#                                     Clade(branch_length=0.09696514423076925, name='[Phodopus_roborovskii]')
#                     Clade(branch_length=0.003336275540865392, name='Inner13')
#                         Clade(branch_length=0.00862849308894232, name='[Piliocolobus_tephrosceles]')
#                         Clade(branch_length=0.001948429987980775, name='Inner12')
#                             Clade(branch_length=0.0028336409684065512, name='Inner10')
#                                 Clade(branch_length=0.0009598691239316205, name='[Rhinopithecus_bieti]')
#                                 Clade(branch_length=1.669337606837601e-06, name='[Rhinopithecus_roxellana]')
#                             Clade(branch_length=0.010627897493131862, name='[Trachypithecus_francoisi]')
#         Clade(branch_length=0.004207669771634602, name='[Macaca_thibetana_thibetana]')
#         Clade(branch_length=0.0006000225360576882, name='[Macaca_nemestrina]')

# %%
# para guardar a árvore filogenética criada num ficheiro 

Phylo.write(tree, "tree_nlrp3.xml", "phyloxml")
# Out:
# 1

# %%
# para criar uma visão mais intuitiva e gráfica da árvore

fig = plt.figure(figsize=(15, 10), dpi=100)
matplotlib.rc('font', size=12)
matplotlib.rc('xtick', labelsize=10)
matplotlib.rc('ytick', labelsize=10)
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(tree, axes=axes)
fig.savefig("tree_nlrp3")

# %% [markdown]
# #### Proteína isoforma 1 codificada pelo gene IL13

# %% [markdown]
# O mesmo procedimento foi realizado para a proteina codificado pelo gene IL13

# %%
with open("il13.aln","r") as aln: 
    alignment = AlignIO.read(aln, "clustal")
print(type(alignment))
# Out:
# <class 'Bio.Align.MultipleSeqAlignment'>

# %%
# utilizando o modelo identity do DistanceCalculator:
calculator = DistanceCalculator('identity')

# calcula-se a matriz de distâncias entre as sequências dos organismos através do alinhamento múltiplo utilizado e obtido do Clustal Omega:
distance_matrix = calculator.get_distance(alignment)

print(distance_matrix)
# Out:
# [Phacochoerus_africanus]    0.000000
# [Lagothrix_lagotricha]  0.209302    0.000000
# [Pithecia_pithecia] 0.209302    0.017442    0.000000
# [Aotus_nancymaae]   0.203488    0.011628    0.005814    0.000000
# [Callithrix_jacchus]    0.203488    0.017442    0.011628    0.005814    0.000000
# [Macaca_mulatta]    0.226744    0.087209    0.087209    0.081395    0.081395    0.000000
# [Theropithecus_gelada]  0.308140    0.162791    0.162791    0.156977    0.156977    0.110465    0.000000
# [Macaca_fascicularis]   0.441860    0.296512    0.296512    0.290698    0.290698    0.238372    0.156977    0.000000
# [Gorilla_gorilla_gorilla]   0.441860    0.308140    0.308140    0.302326    0.302326    0.273256    0.197674    0.075581    0.000000
# [Nomascus_leucogenys]   0.290698    0.180233    0.180233    0.174419    0.174419    0.139535    0.058140    0.215116    0.186047    0.000000
# IL13_HUMAN  0.290698    0.162791    0.162791    0.156977    0.156977    0.122093    0.040698    0.197674    0.168605    0.029070    0.000000
# [Hylobates_lar] 0.203488    0.081395    0.081395    0.075581    0.075581    0.040698    0.116279    0.267442    0.244186    0.098837    0.093023    0.000000
# [Pan_paniscus]  0.430233    0.296512    0.296512    0.290698    0.290698    0.255814    0.168605    0.046512    0.029070    0.168605    0.151163    0.226744    0.000000
# [Pan_troglodytes]   0.290698    0.156977    0.156977    0.151163    0.151163    0.116279    0.029070    0.186047    0.168605    0.029070    0.011628    0.087209    0.139535    0.000000
# [Pongo_abelii]  0.296512    0.162791    0.162791    0.156977    0.156977    0.122093    0.034884    0.191860    0.174419    0.034884    0.017442    0.093023    0.145349    0.005814    0.000000
# [Pongo_pygmaeus]    0.436047    0.302326    0.302326    0.296512    0.296512    0.261628    0.174419    0.052326    0.034884    0.174419    0.156977    0.232558    0.005814    0.145349    0.139535    0.000000
# [Hylobates_moloch]  0.424419    0.302326    0.302326    0.296512    0.296512    0.261628    0.191860    0.058140    0.040698    0.168605    0.162791    0.232558    0.023256    0.162791    0.168605    0.029070    0.000000
# [Symphalangus_syndactylus]  0.430233    0.308140    0.308140    0.302326    0.302326    0.267442    0.197674    0.075581    0.046512    0.174419    0.168605    0.226744    0.029070    0.168605    0.174419    0.034884    0.017442    0.000000
#     [Phacochoerus_africanus]    [Lagothrix_lagotricha]  [Pithecia_pithecia] [Aotus_nancymaae]   [Callithrix_jacchus]    [Macaca_mulatta]    [Theropithecus_gelada]  [Macaca_fascicularis]   [Gorilla_gorilla_gorilla]   [Nomascus_leucogenys]   IL13_HUMAN  [Hylobates_lar] [Pan_paniscus]  [Pan_troglodytes]   [Pongo_abelii]  [Pongo_pygmaeus]    [Hylobates_moloch]  [Symphalangus_syndactylus]

# %%
# utilizando o calculator criado anteriormente para o constructor da árvore:
constructor = DistanceTreeConstructor(calculator)

# constrói-se a árvore filogenética resultante do alinhamento múltiplo:
tree = constructor.build_tree(alignment)
tree.rooted = True

print(tree)
# Out:
# Tree(rooted=True)
#     Clade(branch_length=0, name='Inner16')
#         Clade(branch_length=0.005268895348837219, name='Inner13')
#             Clade(branch_length=0.0723110465116279, name='Inner11')
#                 Clade(branch_length=0.008085029069767463, name='[Hylobates_lar]')
#                 Clade(branch_length=0.004996366279069742, name='Inner10')
#                     Clade(branch_length=0.02808347176079734, name='Inner9')
#                         Clade(branch_length=0.1702398255813954, name='[Phacochoerus_africanus]')
#                         Clade(branch_length=0.02888808139534882, name='Inner8')
#                             Clade(branch_length=0.0014534883720930397, name='Inner7')
#                                 Clade(branch_length=0.0031976744186046485, name='[Callithrix_jacchus]')
#                                 Clade(branch_length=0.002616279069767455, name='Inner6')
#                                     Clade(branch_length=2.7755575615628914e-17, name='[Aotus_nancymaae]')
#                                     Clade(branch_length=0.005813953488372076, name='[Pithecia_pithecia]')
#                             Clade(branch_length=0.010174418604651167, name='[Lagothrix_lagotricha]')
#                     Clade(branch_length=0.02424210963455148, name='[Macaca_mulatta]')
#             Clade(branch_length=0.007721656976744193, name='Inner12')
#                 Clade(branch_length=0.12436409883720928, name='Inner5')
#                     Clade(branch_length=0.010901162790697666, name='Inner4')
#                         Clade(branch_length=0.010286225402504484, name='Inner1')
#                             Clade(branch_length=0.011627906976744207, name='[Symphalangus_syndactylus]')
#                             Clade(branch_length=0.005813953488372103, name='[Hylobates_moloch]')
#                         Clade(branch_length=0.001341681574239681, name='Inner3')
#                             Clade(branch_length=0.004983388704318942, name='Inner2')
#                                 Clade(branch_length=0.00542635658914728, name='[Pongo_pygmaeus]')
#                                 Clade(branch_length=0.00038759689922482354, name='[Pan_paniscus]')
#                             Clade(branch_length=0.02408637873754152, name='[Gorilla_gorilla_gorilla]')
#                     Clade(branch_length=0.035610465116279084, name='[Macaca_fascicularis]')
#                 Clade(branch_length=0.01662427325581392, name='[Theropithecus_gelada]')
#         Clade(branch_length=0.0024981831395348535, name='Inner15')
#             Clade(branch_length=0.006994912790697708, name='IL13_HUMAN')
#             Clade(branch_length=0.02207485465116281, name='[Nomascus_leucogenys]')
#         Clade(branch_length=0.003315770348837222, name='Inner14')
#             Clade(branch_length=0.005783672480620143, name='[Pongo_abelii]')
#             Clade(branch_length=3.028100775196059e-05, name='[Pan_troglodytes]')

# %%
# para guardar a árvore filogenética criada num ficheiro 

Phylo.write(tree, "tree_il13.xml", "phyloxml")
# Out:
# 1

# %%
# para criar uma visão mais intuitiva e gráfica da árvore

fig = plt.figure(figsize=(15, 10), dpi=100)
matplotlib.rc('font', size=12)
matplotlib.rc('xtick', labelsize=10)
matplotlib.rc('ytick', labelsize=10)
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(tree, axes=axes)
fig.savefig("tree_il13")
